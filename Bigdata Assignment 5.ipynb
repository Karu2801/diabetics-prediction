# %% [markdown]
# **INTRODUCTION TO BIGDATA AND DATASCIENCE**
#
#
# **ASSIGNMENT- 5**
#
# **Name  - Karunya Mekala**
#
# **Student ID -11818036**

# %% [markdown]
# My EUID is "km1492",the last digit of it is 2 ,By visualization task , I have added 1 to last digit of my EUID which is ‘2+1=3’, So here I have applied Histogram .

# %%
import matplotlib.pyplot as mat

Average_Expenditure = [665493030, 861910090, 9081374020, 1197655010, 1373946006,149646008]
mat.hist(Average_Expenditure, bins=6, color='pink', edgecolor='black')  
mat.xlabel("Average Expenditure")
mat.ylabel("Frequency")
mat.title("Histogram of Average Expenditure")
mat.show()

# %% [markdown]
# **Explanation:**
#
# Here I have imported libaries i.e matplotlib.pyplot as mat.Next I have created list and named it as 'Average_Expenditure','Frequency','Histogram of Average Expenditure'. The values in Average Expenditure are (665493030,861910090,9081374020,11997655010,1373946006,149646008)
#
# Here I have used 'hist' function and given the color as 'pink' ,bins=6, edgecolor='black'
#
# And here I have set 'Y-axis' as Frequency ,'X-axis' as Average Expenditure and Given title as "Histogram of Average Expenditure"
#
# Finally, by using show() I have displayed the "Histogram of Average Expenditure"
