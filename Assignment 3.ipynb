# %%
import pandas as p
d = p.read_csv("/Users/sharanyabobbala/Desktop/Assignment 3/ElectronicsData.csv")
# Out:
#   Cell In[2], line 2
#     d = p.read_csv("C:\Users\karun\Downloads\CVS.csv")
#                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
d.head(10)
# Out:
#            Sub Category                       Price  \
# 0             Batteries                     $20.99
# 1             Batteries                     $20.99
# 2             Batteries                     $20.99
# 3             Batteries                     $18.99
# 4             Batteries                     $14.99
# 5             Batteries                     $18.99
# 6             Batteries      $299.99through-$449.99
# 7             Batteries  $1,149.99through-$1,499.99
# 8  Cameras & Camcorders                    $289.99
# 9  Cameras & Camcorders                    $399.99
#
#                            Discount  \
# 0                       No Discount
# 1                       No Discount
# 2                       No Discount
# 3                       No Discount
# 4                       No Discount
# 5                       No Discount
# 6  Special Event - Ends on 01/21/24
# 7  Special Event - Ends on 01/21/24
# 8       Price valid through 1/21/24
# ...

# %%
print(d.loc[4])#reading specific row
# Out:
# Sub Category                                            Batteries
# Price                                                     $14.99
# Discount                                              No Discount
# Rating             Rated 4.8 out of 5 stars based on 125 reviews.
# Title              Duracell 2032 Lithium Coin Batteries, 12-count
# Currency                                                        $
# Feature         Our Longest Lasting Lithium Coin Battery Ever ...
# Name: 4, dtype: object

# %%
print(d.loc[10:15,['Sub Category','Price']])
# Out:
#                Sub Category     Price
# 10     Cameras & Camcorders  $429.99
# 11     Cameras & Camcorders  $239.97
# 12     Cameras & Camcorders  $349.99
# 13     Cameras & Camcorders  $839.99
# 14     Cameras & Camcorders  $849.99
# 15  Desktop Computers & PCs  $649.99

# %%
print(d.loc[:15,['Sub Category','Title','Rating']])
# Out:
#                Sub Category  \
# 0                 Batteries
# 1                 Batteries
# 2                 Batteries
# 3                 Batteries
# 4                 Batteries
# 5                 Batteries
# 6                 Batteries
# 7                 Batteries
# 8      Cameras & Camcorders
# 9      Cameras & Camcorders
# 10     Cameras & Camcorders
# 11     Cameras & Camcorders
# 12     Cameras & Camcorders
# 13     Cameras & Camcorders
# 14     Cameras & Camcorders
# 15  Desktop Computers & PCs
#
#                                                 Title  \
# 0   Duracell Coppertop Alkaline AA Batteries, 40-c...
# 1   Duracell Coppertop Alkaline AAA Batteries, 40-...
# 2             Duracell 9V Alkaline Batteries, 8-count
# 3             Duracell C Alkaline Batteries, 14-count
# 4      Duracell 2032 Lithium Coin Batteries, 12-count
# 5             Duracell D Alkaline Batteries, 14-count
# 6         Jackery Explorer 550 Portable Power Station
# ...

# %%
print(d.loc[20:24,['Sub Category','Currency','Price']])
# Out:
#                Sub Category Currency       Price
# 20  Desktop Computers & PCs        $  $1,399.99
# 21  Desktop Computers & PCs        $    $599.99
# 22  Desktop Computers & PCs        $  $1,249.99
# 23  Desktop Computers & PCs        $  $1,099.99
# 24  Desktop Computers & PCs        $    $999.99

# %%
c = d.loc[:, ['Sub Category']]#reading specific column
print(c)
# Out:
#                Sub Category
# 0                 Batteries
# 1                 Batteries
# 2                 Batteries
# 3                 Batteries
# 4                 Batteries
# ..                      ...
# 638  Video Games & Consoles
# 639  Video Games & Consoles
# 640  Video Games & Consoles
# 641  Video Games & Consoles
# 642  Video Games & Consoles
#
# [643 rows x 1 columns]

# %%
d1 = p.read_excel("/Users/sharanyabobbala/Desktop/Assignment 3/AmazonBooks.xlsx")

# %%
print(d1)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 595  Live Free Or Die: America (and the World) on t...
# 596                                 Burn After Writing
# 597  Get Out of Your Head: Stopping the Spiral of T...
# 598  Human Body Activity Book for Kids: Hands-On Fu...
# 599                                 Educated: A Memoir
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
d1.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
print(d1.loc[7])#reading specific row
# Out:
# Name           A Gentleman in Moscow: A Novel
# Author                            Amor Towles
# User Rating                               4.7
# Reviews                                 19699
# Price                                      15
# Year                                     2017
# Genre                                 Fiction
# Name: 7, dtype: object

# %%
c1 = d1.loc[:, ['Author']]#reading specific column
print(c1)
# Out:
#                        Author
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# ..                        ...
# 595              Sean Hannity
# 596              Sharon Jones
# 597              Jennie Allen
# 598              Katie Stokes
# 599            Tara Westover
#
# [600 rows x 1 columns]

# %%
print (d1.loc[[41,79,8],['Author','Name']])# multi-axes indexing funtion
# Out:
#              Author                                           Name
# 41  Bill Martin Jr.       Brown Bear, Brown Bear, What Do You See?
# 79     Stephen King                          Doctor Sleep: A Novel
# 8       James Comey  A Higher Loyalty: Truth, Lies, and Leadership

# %%
print (d1.loc[[41,79,8],['Author','User Rating']])# multi-axes indexing funtion
# Out:
#              Author  User Rating
# 41  Bill Martin Jr.          4.9
# 79     Stephen King          4.7
# 8       James Comey          4.7

# %%
import pandas as pd
with pd.ExcelFile('/Users/sharanyabobbala/Desktop/Assignment 3/UPDOWND.xlsx') as xls:
    df1=pd.read_excel(xls, 'Sheet1')
    df2=pd.read_excel(xls, 'Sheet2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[111], line 4
#       2 with pd.ExcelFile('/Users/sharanyabobbala/Desktop/Assignment 3/UPDOWND.xlsx') as xls:
#       3     df1=pd.read_excel(xls, 'Sheet1')
# ----> 4     df2=pd.read_excel(xls, 'Sheet2')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/excel/_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
# ...
