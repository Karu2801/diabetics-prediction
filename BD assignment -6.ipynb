# %% [markdown]
# **INTRODUCTION TO BIGDATA AND DATASCIENCE**
#
# **ASSIGNMENT -6**
#
# **NAME - Karunya Mekala**
#
# **Student Id -11818036**

# %% [markdown]
# Here I have imported pandas as kv1. In 'g' dictionary I have taken Name and Age .And created dataframe which is v1. And here I have applied  mode function on v1.

# %%
import pandas as kv1
g = {'Name':kv1.Series(['Harshini','Dimple','Sai charan','Supriya','Karunya','Vikas','Ram', 'Keerthi','Leo','Sharanya','Thanmai','Thanu Sree']),
     'Age':kv1.Series([24,23,19,25,27,26,22,24,30,21,15,36])}
v1 = kv.DataFrame(g)
print(v1.mode())
# Out:
#           Name   Age
# 0       Dimple  24.0
# 1     Harshini   NaN
# 2      Karunya   NaN
# 3      Keerthi   NaN
# 4          Leo   NaN
# 5          Ram   NaN
# 6   Sai charan   NaN
# 7     Sharanya   NaN
# 8      Supriya   NaN
# 9      Thanmai   NaN
# 10  Thanu Sree   NaN
# 11       Vikas   NaN
