# %% [markdown]
# **INTRODUCTION TO BIGDATA AND DATASCIENCE**
#
# **Assignment -4**
#
# **Name : Karunya Mekala**
#
# **Student ID: 11818036**

# %% [markdown]
# **My student EUID  is 'km1492' so I have used my last digit of EUID i.e. 2, 2+1 =3. So, here I am applying Cleansing '3' method.
# Here I have imported pandas as dk and given random letters in Index and Random number names in colunm.By reindex I have reindexed 'k','l','v','s' with 'k','l','v','p' and assigned it as NaN with 0.**

# %%
import pandas as dk
import numpy as np
dk = dk.DataFrame(np.random.randn(4, 5), index=['k', 'l', 'v','s'],columns=['five','six', 'seven','eight','nine'])
dk = dk.reindex(['k', 'l', 'v','p'])
print (dk)
print ("NaN replaced with '0':")
print (dk.fillna(0))
# Out:
#        five       six     seven     eight      nine
# k -0.818535  0.398442 -0.726431 -1.879236 -1.680141
# l  1.320713  0.316015 -0.141816  1.590894 -0.209861
# v  0.204149  0.391052  0.523051  2.120553 -0.227571
# p       NaN       NaN       NaN       NaN       NaN
# NaN replaced with '0':
#        five       six     seven     eight      nine
# k -0.818535  0.398442 -0.726431 -1.879236 -1.680141
# l  1.320713  0.316015 -0.141816  1.590894 -0.209861
# v  0.204149  0.391052  0.523051  2.120553 -0.227571
# p  0.000000  0.000000  0.000000  0.000000  0.000000
