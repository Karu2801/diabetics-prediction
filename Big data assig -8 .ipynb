# %% [markdown]
# **INTRODUCTION TO BIGDATA AND DATASCIENCE**
#
# **NAME: Karunya Mekala**
#
# **Student id: 11818036**
#
# **Assignment-8**

# %%
import matplotlib.pyplot as km
from sklearn.neighbors import KNeighborsClassifier
xCoords = [8, 5, 7, 4, 9, 16, 10, 3, 11, 1]
yCoords = [18, 19, 20, 19, 10, 29, 24, 12, 23, 14]
categories = [0, 0, 1, 0, 1, 0, 0, 1, 0, 0]
dataPoints = list(zip(tCoords, vCoords))
print("Data points and their categories:", dataPoints)

km.scatter(xCoords, yCoords, c=categories, cmap='viridis', marker='o', edgecolor='k', label="Existing Data Points")
km.xlabel("x Coordinate")
km.ylabel("y Coordinate")
km.title("k-NN Classification with k=3")
knnModel = KNeighborsClassifier(n_neighbors=3)
knnModel.fit(dataPoints, categories)
testx = 15
testy = 23
testPoint = [(testx, testy)]
predictedCategory = knnModel.predict(testPoint)
print("Predicted category for test point:", predictedCategory)
km.scatter(testx, testy, c=predictedCategory, cmap='viridis', marker='*', s=250, edgecolor='pink', label="Test Data Point")
km.text(testx - 1.4, testy - 0.6, s=f"Test point, category: {predictedCategory[0]}", color='blue')
km.legend()
km.show()
# Out:
# Data points and their categories: [(8, 18), (5, 19), (7, 20), (4, 19), (9, 10), (16, 29), (10, 24), (3, 12), (11, 23), (1, 14)]
# Predicted category for test point: [0]

# %% [markdown]
# **Explanation**
#
#
# The code above, is a Python script that implements classifying a test point by using a small amounts of data by employing k-nearest neighbors (k-NN) algorithm. To start with it calls the required libraries as matplotlib.pyplot for graph developments and KNeighborsClassifier from the sklearn for the k-NN model.
#
# A few lists are defined: xCoords, yCoords: These are the data points on the x and y axes respectively, categories: holds the category for each of the data point, 0 or 1. Those three lists are joined through zip to form dataPoints, a list of a two elements tuples that indicate location of each item in a two-dimensional space.
#
# The points are plotted on an xy-plane creating a scatter plot; the points of the scatter plot can be colored based on category. Most of what was filmed is very violent, so labels and a title are placed to define what the plot of the film is about. The code then trains the k-NN model with n_neighbors = 3, in other words it will take into consideration only the three nearest neighbours for classification of new points. The model is then binned with the data points and categories.
#
# Besides, to illustrate, the classification using the k-NN model, a new test point is created, (15, 23), then, its category is predicted by the trained k-NN model. The predicted category is echoed on the console. Last, the code brings the test point with different color and label to scatter the new classification results and it shows the full plot by km.show().
